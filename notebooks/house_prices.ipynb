# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content/drive/My Drive/colab_projects/deep-learning-practice/deep-learning-practice

# %%
#Read data
import numpy as np
import tensorflow as tf

TRAIN_HOUSES_DATA = '/content/sample_data/california_housing_train.csv'
TEST_HOUSES_DATA = '/content/sample_data/california_housing_test.csv'

# %%
# !git status -s
